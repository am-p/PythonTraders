# %% [markdown]
# # Importaciones y conexion a la base de datos

# %%
#!pip install PyMySQL

import yfinance as yf
import requests
import pandas as pd
import tqdm, sys, time, threading
import numpy as np
import datetime
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:@localhost') # connect to server
engine.execute("CREATE DATABASE If NOT EXISTS derivados")

# %%
engine = create_engine('mysql+pymysql://root:@localhost/derivados') # connect to server
conn = engine.connect()

# %% [markdown]
# # Tickers del SP500

# %%
sp500_wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
sp500_wiki = sp500_wiki.loc[~sp500_wiki.Symbol.isin(['BRK.B' ,'BF.B'])]
sp500_wiki
# Out:
#     Symbol             Security SEC filings             GICS Sector  \
# 0      MMM           3M Company     reports             Industrials
# 1      ABT  Abbott Laboratories     reports             Health Care
# 2     ABBV          AbbVie Inc.     reports             Health Care
# 3     ABMD          ABIOMED Inc     reports             Health Care
# 4      ACN        Accenture plc     reports  Information Technology
# ..     ...                  ...         ...                     ...
# 500    YUM      Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA   Zebra Technologies     reports  Information Technology
# 502    ZBH        Zimmer Biomet     reports             Health Care
# 503   ZION        Zions Bancorp     reports              Financials
# 504    ZTS               Zoetis     reports             Health Care
#
#                       GICS Sub-Industry     Headquarters Location  \
# 0              Industrial Conglomerates       St. Paul, Minnesota
# 1                 Health Care Equipment   North Chicago, Illinois
# 2                       Pharmaceuticals   North Chicago, Illinois
# 3                 Health Care Equipment    Danvers, Massachusetts
# 4        IT Consulting & Other Services           Dublin, Ireland
# ..                                  ...                       ...
# 500                         Restaurants      Louisville, Kentucky
# 501  Electronic Equipment & Instruments    Lincolnshire, Illinois
# 502               Health Care Equipment           Warsaw, Indiana
# 503                      Regional Banks      Salt Lake City, Utah
# 504                     Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         1964-03-31     1800         1888
# 2         2012-12-31  1551152  2013 (1888)
# 3         2018-05-31   815094         1981
# 4         2011-07-06  1467373         1989
# ..               ...      ...          ...
# 500       1997-10-06  1041061         1997
# 501       2019-12-23   877212         1969
# 502       2001-08-07  1136869         1927
# 503       2001-06-22   109380         1873
# 504       2013-06-21  1555280         1952
#
# [503 rows x 9 columns]

# %%
sp500_wiki.to_sql(con=conn, name='sp500_tickers', if_exists='replace')

# %%
q = 'ALTER TABLE sp500_tickers MODIFY COLUMN Symbol VARCHAR(255)'
conn.execute(q)

# %%
q = 'ALTER TABLE sp500_tickers ADD PRIMARY KEY(Symbol)'
conn.execute(q)

# %%
# %%time
tickers = pd.read_sql('SELECT Symbol FROM sp500_tickers', conn)
# Out:
# Wall time: 9 ms

# %%
sp500_tickers = tickers.Symbol.tolist()

# %% [markdown]
# # Historicos Yahoo Diarios

# %%
def getDataM(listado, start='2000-01-01', interval='1d', end=None):
    data = yf.download(listado, start=start, end=end, interval=interval, auto_adjust=True)
    return data.swaplevel(i=1, j=0, axis=1)

# %% [markdown]
# ## Descarga de datos

# %%
# %%time
df_sp500 = getDataM(sp500_tickers, start='2018-01-01', interval='1d')
# Out:
# [*********************100%***********************]  503 of 503 completed
# Wall time: 42.6 s

# %% [markdown]
# ## Preparamos la data

# %%
tablas = []
with tqdm.tqdm(total=len(sp500_tickers), file=sys.stdout) as pbar:
    for ticker in sp500_tickers:
        pbar.update()
        tabla = df_sp500[ticker].copy()
        tabla['symbol'] = ticker
        tabla['variacion'] = tabla.Close.pct_change() *100
        tabla['sigma_40'] = tabla.variacion.rolling(40).std() * 250**0.5
        tabla['sigma_120'] = tabla.variacion.rolling(120).std() * 250**0.5
        tabla['sigma_250'] = tabla.variacion.rolling(250).std() * 250**0.5
        tabla['vol_mln'] = tabla.Volume * tabla.Close / 1000000
        tabla = tabla.dropna().round(2)
        tablas.append(tabla)

tabla_daily = pd.concat(tablas)        
tabla_daily
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 503/503 [00:03<00:00, 134.95it/s]
#              Close    High     Low    Open     Volume symbol  variacion  \
# Date
# 2018-12-28  178.15  180.91  177.40  180.44  2311400.0    MMM      -0.70
# 2018-12-31  179.25  180.29  177.33  179.06  1804400.0    MMM       0.62
# 2019-01-02  179.64  179.67  175.64  176.69  2475200.0    MMM       0.22
# 2019-01-03  172.87  177.12  172.05  177.12  3358200.0    MMM      -3.77
# 2019-01-04  179.98  180.60  175.01  175.68  2995100.0    MMM       4.11
# ...            ...     ...     ...     ...        ...    ...        ...
# 2020-10-29  161.19  162.45  158.13  159.46  1539000.0    ZTS       1.58
# 2020-10-30  158.55  161.32  156.25  160.02  2078300.0    ZTS      -1.64
# 2020-11-02  162.89  163.26  160.71  161.31  1516600.0    ZTS       2.74
# 2020-11-03  163.14  165.49  162.90  164.64  1519500.0    ZTS       0.15
# 2020-11-04  175.38  176.13  165.97  165.99  1741405.0    ZTS       7.50
#
#             sigma_40  sigma_120  sigma_250  vol_mln  Adj Close
# Date
# 2018-12-28     28.69      23.97      23.82   411.77        NaN
# 2018-12-31     28.61      23.84      23.83   323.44        NaN
# 2019-01-02     28.61      23.81      23.80   444.63        NaN
# 2019-01-03     30.11      24.38      24.07   580.54        NaN
# 2019-01-04     31.78      25.11      24.43   539.07        NaN
# ...              ...        ...        ...      ...        ...
# 2020-10-29     23.38      23.95      38.44   248.07        NaN
# 2020-10-30     21.55      23.91      38.48   329.51        NaN
# 2020-11-02     22.44      24.14      38.38   247.04        NaN
# 2020-11-03     21.52      23.93      38.37   247.89        NaN
# 2020-11-04     27.09      26.10      39.07   305.41        NaN
#
# [230558 rows x 12 columns]

# %% [markdown]
# ## Guardamos la tabla

# %%
# %%time
tabla_daily.to_sql(con=conn,  name='sp500_daily', if_exists='replace')
# Out:
# Wall time: 10.7 s

# %% [markdown]
# ## Agregamos una PK (recomendable, no necesario)

# %%
q = 'ALTER TABLE sp500_daily ADD id INT NOT NULL AUTO_INCREMENT PRIMARY KEY'
conn.execute(q)

# %% [markdown]
# ## Algunas consultas

# %%
# %%time
pd.read_sql('''SELECT symbol, AVG(sigma_40) AS Sigma_40_AVG , AVG(sigma_250) AS Sigma_250_AVG
                FROM sp500_daily 
                WHERE Date >"2020-06-01" 
                GROUP BY symbol'''
            , conn)
# Out:
# Wall time: 244 ms
#     symbol  Sigma_40_AVG  Sigma_250_AVG
# 0        A     23.998909      36.082909
# 1      AAL     96.273909      98.586636
# 2      AAP     28.922909      47.083364
# 3     AAPL     37.807455      42.332636
# 4     ABBV     22.859091      33.947091
# ..     ...           ...            ...
# 492    YUM     23.970636      43.513818
# 493    ZBH     37.315364      47.215818
# 494   ZBRA     37.353273      49.639091
# 495   ZION     52.042455      49.308273
# 496    ZTS     25.014273      38.568273
#
# [497 rows x 3 columns]

# %%
# %%time
pd.read_sql('''SELECT symbol, STDDEV(variacion)*SQRT(250) AS Sigma
                FROM sp500_daily 
                WHERE Date >"2020-06-01" 
                GROUP BY symbol'''
            , conn)
# Out:
# Wall time: 238 ms
#     symbol      Sigma
# 0        A  22.475962
# 1      AAL  97.271437
# 2      AAP  26.738132
# 3     AAPL  41.730045
# 4     ABBV  27.088709
# ..     ...        ...
# 492    YUM  22.681321
# 493    ZBH  34.470326
# 494   ZBRA  36.565956
# 495   ZION  49.422904
# 496    ZTS  25.547312
#
# [497 rows x 2 columns]

# %%
# %%time
pd.read_sql('''SELECT symbol, STDDEV(variacion)*SQRT(250) AS Sigma, 
                        AVG(sigma_40) AS Sigma_40_AVG , 
                        AVG(sigma_250) AS Sigma_250_AVG
                FROM sp500_daily 
                WHERE Date >"2020-06-01" 
                GROUP BY symbol'''
            , conn).round(1)
# Out:
# Wall time: 249 ms
#     symbol  Sigma  Sigma_40_AVG  Sigma_250_AVG
# 0        A   22.5          24.0           36.1
# 1      AAL   97.3          96.3           98.6
# 2      AAP   26.7          28.9           47.1
# 3     AAPL   41.7          37.8           42.3
# 4     ABBV   27.1          22.9           33.9
# ..     ...    ...           ...            ...
# 492    YUM   22.7          24.0           43.5
# 493    ZBH   34.5          37.3           47.2
# 494   ZBRA   36.6          37.4           49.6
# 495   ZION   49.4          52.0           49.3
# 496    ZTS   25.5          25.0           38.6
#
# [497 rows x 4 columns]

# %% [markdown]
# # Historicos Yahoo 5min

# %%
# %%time
start = (datetime.date.today() - datetime.timedelta(days=30)).isoformat()
df_sp500_5m = getDataM(sp500_tickers, start=start, interval='5m')
# Out:
# [*********************100%***********************]  503 of 503 completed
# Wall time: 44.9 s

# %% [markdown]
# ## Preparamos la data

# %%
tablas = []
with tqdm.tqdm(total=len(sp500_tickers), file=sys.stdout) as pbar:
    for ticker in sp500_tickers:
        pbar.update()
        tabla = df_sp500_5m[ticker].copy()
        tabla['symbol'] = ticker
        tabla['variacion'] = tabla.Close.pct_change() *100
        tabla['sigma_1d'] = tabla.variacion.rolling(78).std() * (78*250)**0.5
        tabla['sigma_5d'] = tabla.variacion.rolling(390).std() * (390*250)**0.5
        tabla['vol_mln'] = tabla.Volume * tabla.Close / 1000000
        tabla = tabla.dropna().round(2)
        tablas.append(tabla)

tabla_5m = pd.concat(tablas)
tabla_5m
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 503/503 [00:03<00:00, 140.42it/s]
#                             Close    High     Low    Open   Volume symbol  \
# Datetime
# 2020-10-12 09:30:00-04:00  169.25  169.65  169.03  169.47  89103.0    MMM
# 2020-10-12 09:35:00-04:00  169.72  169.94  169.28  169.28  18204.0    MMM
# 2020-10-12 09:40:00-04:00  170.14  170.25  169.77  169.77  22934.0    MMM
# 2020-10-12 09:45:00-04:00  170.25  170.47  169.93  170.14  13613.0    MMM
# 2020-10-12 09:50:00-04:00  170.26  170.47  170.12  170.17  17102.0    MMM
# ...                           ...     ...     ...     ...      ...    ...
# 2020-11-04 11:10:00-05:00  172.31  172.50  172.10  172.50  21420.0    ZTS
# 2020-11-04 11:15:00-05:00  172.60  172.60  172.19  172.40  24510.0    ZTS
# 2020-11-04 11:20:00-05:00  173.09  173.33  172.47  172.60  45886.0    ZTS
# 2020-11-04 11:25:00-05:00  172.96  173.24  172.94  173.10   8052.0    ZTS
# 2020-11-04 13:28:34-05:00  175.21  175.21  175.21  175.21      0.0    ZTS
#
#                            variacion  sigma_1d  sigma_5d  vol_mln
# Datetime
# 2020-10-12 09:30:00-04:00      -0.01     14.99     52.81    15.08
# 2020-10-12 09:35:00-04:00       0.28     14.98     52.75     3.09
# 2020-10-12 09:40:00-04:00       0.25     15.42     52.82     3.90
# 2020-10-12 09:45:00-04:00       0.06     15.43     52.77     2.32
# 2020-10-12 09:50:00-04:00       0.01     14.98     52.59     2.91
# ...                              ...       ...       ...      ...
# 2020-11-04 11:10:00-05:00      -0.08     72.37    100.48     3.69
# 2020-11-04 11:15:00-05:00       0.17     72.33    100.46     4.23
# 2020-11-04 11:20:00-05:00       0.28     72.40    100.48     7.94
# 2020-11-04 11:25:00-05:00      -0.08     72.42    100.44     1.39
# 2020-11-04 13:28:34-05:00       1.30     21.21     97.75     0.00
#
# [688846 rows x 10 columns]

# %% [markdown]
# ## Guardamos la tabla

# %%
# %%time
tabla_5m.to_sql(con=conn,  name='sp500_5m', if_exists='replace')
# Out:
# Wall time: 31.5 s

# %% [markdown]
# ## Agregamos una PK (recomendable, no necesario)

# %%
q = 'ALTER TABLE sp500_5m ADD id INT NOT NULL AUTO_INCREMENT PRIMARY KEY'
conn.execute(q)

# %% [markdown]
# ## Algunas Consultas

# %% [markdown]
# Volatilidades de alta fracuencia:
#
# Para los ultimos 10 (n) dias:
#  * La volatilidad anualizada de los movimientos cada 5min
#  * El pico de un rolling_1_dia del std() anualizado de las velas de 5min
#  * El pico de un rolling_5_dias del std() anualizado de las velas de 5min

# %%
# %%time
pd.read_sql('''SELECT symbol, STDDEV(variacion)*SQRT(250*78) AS Sigma_10d, 
                        MAX(sigma_1d) AS pico_sigma_r1d , 
                        MAX(sigma_5d) AS pico_sigma_r5d
                FROM sp500_5m 
                WHERE Datetime > DATE_SUB(NOW(), INTERVAL 10 day) 
                GROUP BY symbol'''
            , conn).round(1)
# Out:
# Wall time: 1.01 s
#     symbol  Sigma_10d  pico_sigma_r1d  pico_sigma_r5d
# 0        A       31.9            42.9            73.5
# 1      AAL       54.2            80.0           135.4
# 2      AAP       35.7            49.4            86.4
# 3     AAPL       44.3            66.8           109.8
# 4     ABBV       70.8           156.6           192.2
# ..     ...        ...             ...             ...
# 498    YUM       37.1            55.4            91.8
# 499    ZBH       38.6            54.4            90.4
# 500   ZBRA       55.3           117.5           140.9
# 501   ZION       72.4           165.5           186.0
# 502    ZTS       41.4            72.9           101.5
#
# [503 rows x 4 columns]

# %% [markdown]
# # Calendario Yahoo

# %% [markdown]
# ## Sin hilos

# %%
tickers = pd.read_sql('SELECT symbol FROM sp500_tickers', conn).symbol.tolist()
tickers = tickers[:12]

# %%
# %%time
earnings = []
for ticker in tickers:
    try:
        data = yf.Ticker(ticker)
        dicc = data.calendar.iloc[:,0].to_dict()
        dicc['symbol'] = ticker
        earnings.append(dicc)
        print(ticker, end=' ')
    except:
        print(f'\nNo se pudo usar data de {ticker}\n')        
        
sp500_earnings = pd.DataFrame(earnings)
sp500_earnings
# Out:
# MMM ABT ABBV ABMD ACN ATVI ADBE AMD AAP AES AFL A Wall time: 35 s
#    Earnings Date  Earnings Average  Earnings Low  Earnings High  \
# 0     2021-01-26              2.24          2.14           2.34
# 1     2021-01-20              1.36          1.32           1.40
# 2     2020-10-30              2.86          2.83           2.90
# 3     2021-02-04              1.12          1.01           1.21
# 4     2020-12-17              2.05          1.93           2.22
# 5     2021-02-04              1.17          1.09           1.45
# 6     2020-12-09              2.66          2.63           2.82
# 7     2021-01-26              0.46          0.44           0.49
# 8     2020-11-10              2.66          2.14           3.10
# 9     2020-11-06              0.43          0.41           0.45
# 10    2021-02-02              1.04          1.00           1.07
# 11    2020-11-23              0.93          0.85           1.09
#
#     Revenue Average  Revenue Low  Revenue High symbol
# 0        8258220000   8153100000    8356000000    MMM
# 1        9969880000   9764000000   10299600000    ABT
# 2       13744600000  13671000000   13821500000   ABBV
# 3         227850000    221000000     243200000   ABMD
# 4       11366500000  11186700000   11529000000    ACN
# 5        2799380000   2716000000    3108000000   ATVI
# 6        3359350000   3347000000    3404000000   ADBE
# 7        3009100000   2994000000    3071000000    AMD
# 8        2476070000   2421900000    2557000000    AAP
# 9        2701240000   2649000000    2753470000    AES
# 10       5420460000   5333000000    5507910000    AFL
# 11       1403890000   1386900000    1423890000      A

# %% [markdown]
# ## Con Hilos prueba

# %%
def get_earnings(ticker):
    try:
        print(ticker, end=' ')
        data = yf.Ticker(ticker)
        dicc = data.calendar.iloc[:,0].to_dict()
        dicc['symbol'] = ticker
        return pd.DataFrame.from_dict(dicc, orient='index').T
    except:
        print(f'\nNo se pudo usar data de {ticker}\n')
        columns = ['Earnings Date','Earnings Average', 'Earnings Low', 'Earnings High', 
                   'Revenue Average', 'Revenue Low', 'Revenue High', 'symbol']
        df = pd.DataFrame(columns=columns)
        df.loc[0,'symbol'] = ticker
        return df

get_earnings('AAPL')
# Out:
# AAPL
#   Earnings Date Earnings Average Earnings Low Earnings High Revenue Average  \
# 0    2021-01-26             1.38         1.23          1.58    101703000000
#
#    Revenue Low  Revenue High symbol
# 0  97414000000  110875000000   AAPL

# %%
n_threads = 4
subs = np.array_split(tickers, n_threads)
subs
# Out:
# [array(['MMM', 'ABT', 'ABBV'], dtype='<U4'),
#  array(['ABMD', 'ACN', 'ATVI'], dtype='<U4'),
#  array(['ADBE', 'AMD', 'AAP'], dtype='<U4'),
#  array(['AES', 'AFL', 'A'], dtype='<U4')]

# %%
# %%time

dfs = []
def worker(tickers):
    for ticker in tickers:
        df  = get_earnings(ticker)
        dfs.append(df)
    return df

    
threads = []
for i in range(n_threads):
    t = threading.Thread(target=worker, args=(subs[i],))
    threads.append(t)
    t.start()
    
for t in threads:
    t.join()
    
sp500_earnings = pd.concat(dfs)
sp500_earnings
# Out:
# MMM ABMD ADBE AES AFL ACN AMD ABT ATVI AAP ABBV A Wall time: 9.66 s
#   Earnings Date Earnings Average Earnings Low Earnings High Revenue Average  \
# 0    2020-11-06             0.43         0.41          0.45      2701240000
# 0    2021-02-04             1.12         1.01          1.21       227850000
# 0    2020-12-09             2.66         2.63          2.82      3359350000
# 0    2021-01-26             2.24         2.14          2.34      8258220000
# 0    2020-12-17             2.05         1.93          2.22     11366500000
# 0    2021-01-26             0.46         0.44          0.49      3009100000
# 0    2021-01-20             1.36         1.32           1.4      9969880000
# 0    2021-02-02             1.04            1          1.07      5420460000
# 0    2020-10-30             2.86         2.83           2.9     13744600000
# 0    2020-11-10             2.66         2.14           3.1      2476070000
# 0    2021-02-04             1.17         1.09          1.45      2799380000
# 0    2020-11-23             0.93         0.85          1.09      1403890000
#
#    Revenue Low Revenue High symbol
# 0   2649000000   2753470000    AES
# 0    221000000    243200000   ABMD
# 0   3347000000   3404000000   ADBE
# 0   8153100000   8356000000    MMM
# 0  11186700000  11529000000    ACN
# 0   2994000000   3071000000    AMD
# 0   9764000000  10299600000    ABT
# 0   5333000000   5507910000    AFL
# 0  13671000000  13821500000   ABBV
# 0   2421900000   2557000000    AAP
# 0   2716000000   3108000000   ATVI
# 0   1386900000   1423890000      A

# %% [markdown]
# ## Con hilos full

# %%
tickers = pd.read_sql('SELECT symbol FROM sp500_tickers', conn).symbol.tolist()

# %%
n_threads = 8
subs = np.array_split(tickers, n_threads)

# %%
# %%time

dfs = []
def worker(tickers):
    for ticker in tickers:
        df  = get_earnings(ticker)
        dfs.append(df)
    return df

    
t0 = time.time()
threads = []
for i in range(n_threads):
    t = threading.Thread(target=worker, args=(subs[i],))
    threads.append(t)
    t.start()
    
for t in threads:
    t.join()

print('\n')
sp500_earnings = pd.concat(dfs)
sp500_earnings
# Out:
# MMM BK CTVA FE INTU MSFT PLD TJX TSCO ABT FRC MAA PRU COST ISRG BAX MHK TT FISV ABBV CCI IVZ PEG BDX TDG FLT ABMD TAP CSX IPGP PSA BBY TRV FLIR MDLZ IQV PHM ACN CMI BIO TFC FLS MNST IRM PVH ATVI CVS TWTR BIIB FMC JKHY MCO ADBE QRVO DHI TYL BLK F J AMD MS PWR DHR TSN BA FTNT JBHT MOS QCOM AAP DRI UDR BKNG SJM FTV MSI DGX AES DVA BWA ULTA JNJ FBHS MSCI AFL RL DE BXP USB JCI FOXA MYL A RJF DAL BSX JPM UAA FOX NDAQ XRAY BMY APD RTX UA
# No se pudo usar data de FOX
#
# BEN JNPR NOV DVN AKAM O AVGO FCX UNP KSU NTAP DXCM ALK REG BR GPS UAL K NFLX ALB FANG REGN CHRW GRMN UNH KEY NWL RF ARE COG DLR IT UPS NEM KEYS RSG ALXN CDNS DFS GD URI NWSA KMB ALGN CPB DISCA RMD UHS GE NWS ALLE KIM COF DISCK RHI GIS UNM
# No se pudo usar data de NWS
#
# NEE LNT KMI CAH ROK GM VFC DISH NLSN ALL KLAC KMX GPC ROL DG VLO NKE GOOGL KHC CCL GILD ROP NI VAR DLTR KR GOOG CARR ROST GL NSC VTR D
# No se pudo usar data de GOOG
#
# MO LB CTLT RCL GPN NTRS DPZ AMZN VRSN LHX CAT SPGI GS NOC AMCR DOV VRSK LH CBOE CRM GWW NLOK AEE VZ LRCX DOW CBRE SBAC NCLH HAL AAL LW VRTX DTE CDW SLB NRG LVS HBI DUK VIAC AEP CE STX NUE LEG DRE AXP V HIG CNC SEE LDOS NVDA DD HAS VNT AIG CNP SRE NVR LEN DXC
# No se pudo usar data de VNT
#
# VNO HCA AMT CERN NOW ORLY LLY VMC EMN PEAK AWK CF SHW LNC OXY ETN WRB HSIC AMP SCHW SPG LIN EBAY ODFL WAB HSY ABC CHTR SWKS LYV ECL WMT OMC AME HES CVX SLG LKQ WBA EIX HPE AMGN OKE CMG SNA LMT DIS EW HLT APH ORCL CB SO WM L EA ADI OTIS HFC CHD LUV LOW WAT EMR HOLX ANSS PCAR CI SWK WEC LUMN HD ETR PKG ANTM CINF WFC SBUX LYB HON PH EOG AON CTAS WELL STT PAYX MTB HRL EFX AOS WST STE CSCO HST MRO PAYC EQIX APA SYK C WDCMPC  PYPL HWM EQR AIV SIVB CFG MKTX WU HPQ PNR ESS AAPL SYF CTXS WRK MAR HUM PBCT EL AMAT CLX SNPS MMC WY HBAN PEP ETSY APTV SYY CME WHR MLM HII PKI ADM EVRG CMS TMUS MAS WMB IEX ANET PRGO ES KO TROW MA WLTW IDXX PFE RE AJG CTSH TTWOWYNN  MKC INFO PM AIZ EXC CL MXIM TPR XEL PSX ITW EXPE CMCSA T MCD TGT PNW XRX ILMN EXPD ATO CMA TEL PXD INCY MCK XLNX ADSK EXR CAG FTI PNC MDT XYL IR ADP XOM CXO TDY POOL YUM MRK INTC FFIV AZO COP TFX ICE MET PPG ZBRA AVB FB ED TER ZBH IBM MTD PPL FAST AVY STZ TXN IP ZION MGM PFGFRT  BKR COO IPG ZTS MCHP TXT PG FDX BLL CPRT IFF PGR TMO MU FIS BAC GLW TIF FITB
#
# Wall time: 4min 43s
#    Earnings Date Earnings Average Earnings Low Earnings High Revenue Average  \
# 0     2020-11-17             0.39          0.3          0.49      9333530000
# 0     2021-01-26             2.24         2.14          2.34      8258220000
# 0     2020-11-02              0.5         0.46          0.53      2845270000
# 0     2021-01-27             1.64         1.57          1.86     40202200000
# 0     2021-01-20             0.37         0.33          0.43       988480000
# ..           ...              ...          ...           ...             ...
# 0     2020-10-29             1.63         1.53          1.75      3417490000
# 0     2021-01-19              0.5         0.45          0.57     20213400000
# 0     2020-12-03             0.64         0.44          0.86       973110000
# 0     2021-01-27             0.47         0.43           0.5      3147370000
# 0     2021-01-21             0.68          0.6          0.81      1914370000
#
#     Revenue Low Revenue High symbol
# 0    8787000000   9917000000    TJX
# 0    8153100000   8356000000    MMM
# 0    2627000000   3180430000     FE
# 0   39888000000  41145000000   MSFT
# 0     974600000   1001400000    PLD
# ..          ...          ...    ...
# 0    3325000000   3532700000    FIS
# 0   19716000000  20731000000    BAC
# 0     908000000   1053020000    TIF
# 0    3089000000   3195000000    GLW
# 0    1862000000   1941470000   FITB
#
# [503 rows x 8 columns]

# %%
cols = list(sp500_earnings.columns)
cols = [c.replace(' ','') for c in cols]
sp500_earnings.columns = cols

# %%
sp500_earnings.set_index('symbol', inplace=True)

# %%
# %%time
sp500_earnings.to_sql('sp500_earnings', conn, if_exists='replace')
# Out:
# Wall time: 74.4 ms

# %%
q = 'ALTER TABLE sp500_earnings ADD id INT NOT NULL AUTO_INCREMENT PRIMARY KEY'
conn.execute(q)

# %% [markdown]
# ## Algunas consultas

# %%
hoy = datetime.date.today().isoformat()

fecha_limite = datetime.date.today() + datetime.timedelta(days=15)
fecha_limite = fecha_limite.isoformat()

q = f'''SELECT symbol FROM sp500_earnings 
        WHERE EarningsDate < "{fecha_limite}" AND EarningsDate > "{hoy}"   '''

pd.read_sql(q, conn)
# Out:
#    symbol
# 0     TJX
# 1     BDX
# 2     TDG
# 3     FLT
# 4     FLS
# ..    ...
# 79   MCHP
# 80    ZTS
# 81    BLL
# 82   CPRT
# 83    IFF
#
# [84 rows x 1 columns]

# %% [markdown]
# # Opciones desde TDA

# %%
from clase_11_keys import *
c_key = TDA_KEY

# %%
def options(symbol):
    params = {'apikey' : c_key, 'symbol':symbol}
    endpoint = 'https://api.tdameritrade.com/v1/marketdata/chains'
    r = requests.get(url=endpoint ,params=params)
    return r.json()

# %%
ticker = 'GGAL'
chain = options(ticker)
chain
# Out:
# {'symbol': 'GGAL',
#  'status': 'SUCCESS',
#  'underlying': None,
#  'strategy': 'SINGLE',
#  'interval': 0.0,
#  'isDelayed': True,
#  'isIndex': False,
#  'interestRate': 0.1,
#  'underlyingPrice': 7.045,
#  'volatility': 29.0,
#  'daysToExpiration': 0.0,
#  'numberOfContracts': 104,
#  'putExpDateMap': {'2020-11-20:16': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P2.5',
#      'description': 'GGAL Nov 20 2020 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.05,
#      'last': 0.0,
#      'mark': 0.03,
#      'bidSize': 0,
#      'askSize': 124,
#      'bidAskSize': '0X124',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515313242,
#      'netChange': 0.0,
#      'volatility': 253.785,
#      'delta': -0.015,
#      'gamma': 0.01,
#      'theta': -0.004,
#      'vega': 0.001,
#      'rho': 0.0,
#      'openInterest': 0,
#      'timeValue': 0.03,
#      'theoreticalOptionValue': 0.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.02,
#      'markPercentChange': 24900.0,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P5',
#      'description': 'GGAL Nov 20 2020 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 0.07,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 330,
#      'bidAskSize': '0X330',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.01,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604343468735,
#      'quoteTimeInLong': 1604514548758,
#      'netChange': 0.06,
#      'volatility': 111.936,
#      'delta': -0.062,
#      'gamma': 0.071,
#      'theta': -0.006,
#      'vega': 0.002,
#      'rho': 0.0,
#      'openInterest': 158,
#      'timeValue': 0.07,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 379.45,
#      'markChange': 0.04,
#      'markPercentChange': 242.47,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P7.5',
#      'description': 'GGAL Nov 20 2020 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.65,
#      'ask': 0.85,
#      'last': 0.9,
#      'mark': 0.75,
#      'bidSize': 297,
#      'askSize': 279,
#      'bidAskSize': '297X279',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.8,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604347464742,
#      'quoteTimeInLong': 1604515584707,
#      'netChange': 0.05,
#      'volatility': 77.392,
#      'delta': -0.617,
#      'gamma': 0.324,
#      'theta': -0.013,
#      'vega': 0.006,
#      'rho': -0.002,
#      'openInterest': 195,
#      'timeValue': 0.44,
#      'theoreticalOptionValue': 0.75,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 6.28,
#      'markChange': -0.05,
#      'markPercentChange': -5.73,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P10',
#      'description': 'GGAL Nov 20 2020 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 2.85,
#      'ask': 3.1,
#      'last': 3.2,
#      'mark': 2.98,
#      'bidSize': 16,
#      'askSize': 116,
#      'bidAskSize': '16X116',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.97,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1602596520013,
#      'quoteTimeInLong': 1604515616826,
#      'netChange': 0.23,
#      'volatility': 80.685,
#      'delta': -0.973,
#      'gamma': 0.05,
#      'theta': -0.002,
#      'vega': 0.001,
#      'rho': -0.005,
#      'openInterest': 15,
#      'timeValue': 0.24,
#      'theoreticalOptionValue': 2.975,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 7.88,
#      'markChange': 0.01,
#      'markPercentChange': 0.3,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P12.5',
#      'description': 'GGAL Nov 20 2020 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 5.3,
#      'ask': 5.6,
#      'last': 5.58,
#      'mark': 5.45,
#      'bidSize': 99,
#      'askSize': 85,
#      'bidAskSize': '99X85',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 5.45,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1600958499971,
#      'quoteTimeInLong': 1604515586108,
#      'netChange': 0.13,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.0,
#      'rho': 'NaN',
#      'openInterest': 0,
#      'timeValue': 0.12,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 2.39,
#      'markChange': 0.0,
#      'markPercentChange': 0.0,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P15',
#      'description': 'GGAL Nov 20 2020 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 7.7,
#      'ask': 8.1,
#      'last': 7.2,
#      'mark': 7.9,
#      'bidSize': 139,
#      'askSize': 66,
#      'bidAskSize': '139X66',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 7.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1600454148588,
#      'quoteTimeInLong': 1604515586108,
#      'netChange': -0.86,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.001,
#      'rho': 'NaN',
#      'openInterest': 0,
#      'timeValue': -0.76,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -10.82,
#      'markChange': -0.05,
#      'markPercentChange': -0.63,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '17.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_112020P17.5',
#      'description': 'GGAL Nov 20 2020 17.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 10.3,
#      'ask': 10.6,
#      'last': 0.0,
#      'mark': 10.45,
#      'bidSize': 98,
#      'askSize': 62,
#      'bidAskSize': '98X62',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 10.45,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515586108,
#      'netChange': 0.0,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.001,
#      'rho': 'NaN',
#      'openInterest': 0,
#      'timeValue': -0.01,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1605906000000,
#      'daysToExpiration': 16,
#      'expirationType': 'R',
#      'lastTradingDay': 1605920400000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.0,
#      'markPercentChange': 0.0,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}]},
#   '2020-12-18:44': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_121820P2.5',
#      'description': 'GGAL Dec 18 2020 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.35,
#      'last': 0.0,
#      'mark': 0.18,
#      'bidSize': 0,
#      'askSize': 501,
#      'bidAskSize': '0X501',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604503819961,
#      'netChange': 0.0,
#      'volatility': 240.848,
#      'delta': -0.049,
#      'gamma': 0.017,
#      'theta': -0.007,
#      'vega': 0.003,
#      'rho': -0.001,
#      'openInterest': 0,
#      'timeValue': 0.17,
#      'theoreticalOptionValue': 0.175,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1608325200000,
#      'daysToExpiration': 44,
#      'expirationType': 'R',
#      'lastTradingDay': 1608339600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.17,
#      'markPercentChange': 58233.33,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_121820P5',
#      'description': 'GGAL Dec 18 2020 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.05,
#      'ask': 0.2,
#      'last': 0.2,
#      'mark': 0.13,
#      'bidSize': 114,
#      'askSize': 126,
#      'bidAskSize': '114X126',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.15,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604344531056,
#      'quoteTimeInLong': 1604515618212,
#      'netChange': 0.05,
#      'volatility': 88.272,
#      'delta': -0.105,
#      'gamma': 0.083,
#      'theta': -0.004,
#      'vega': 0.004,
#      'rho': -0.001,
#      'openInterest': 12,
#      'timeValue': 0.2,
#      'theoreticalOptionValue': 0.125,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1608325200000,
#      'daysToExpiration': 44,
#      'expirationType': 'R',
#      'lastTradingDay': 1608339600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 33.33,
#      'markChange': -0.03,
#      'markPercentChange': -16.67,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_121820P7.5',
#      'description': 'GGAL Dec 18 2020 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.95,
#      'ask': 1.1,
#      'last': 1.1,
#      'mark': 1.02,
#      'bidSize': 85,
#      'askSize': 42,
#      'bidAskSize': '85X42',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.06,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604428202458,
#      'quoteTimeInLong': 1604515583693,
#      'netChange': 0.04,
#      'volatility': 75.732,
#      'delta': -0.543,
#      'gamma': 0.212,
#      'theta': -0.008,
#      'vega': 0.01,
#      'rho': -0.006,
#      'openInterest': 96,
#      'timeValue': 0.64,
#      'theoreticalOptionValue': 1.025,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1608325200000,
#      'daysToExpiration': 44,
#      'expirationType': 'R',
#      'lastTradingDay': 1608339600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 3.48,
#      'markChange': -0.04,
#      'markPercentChange': -3.57,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_121820P10',
#      'description': 'GGAL Dec 18 2020 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 2.9,
#      'ask': 3.2,
#      'last': 0.0,
#      'mark': 3.05,
#      'bidSize': 141,
#      'askSize': 521,
#      'bidAskSize': '141X521',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 3.09,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515615839,
#      'netChange': 0.0,
#      'volatility': 72.69,
#      'delta': -0.894,
#      'gamma': 0.101,
#      'theta': -0.004,
#      'vega': 0.004,
#      'rho': -0.012,
#      'openInterest': 0,
#      'timeValue': 0.09,
#      'theoreticalOptionValue': 3.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1608325200000,
#      'daysToExpiration': 44,
#      'expirationType': 'R',
#      'lastTradingDay': 1608339600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -0.04,
#      'markPercentChange': -1.27,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_121820P12.5',
#      'description': 'GGAL Dec 18 2020 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 5.3,
#      'ask': 5.6,
#      'last': 0.0,
#      'mark': 5.45,
#      'bidSize': 109,
#      'askSize': 104,
#      'bidAskSize': '109X104',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 5.47,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515610290,
#      'netChange': 0.0,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.0,
#      'rho': 'NaN',
#      'openInterest': 0,
#      'timeValue': -0.01,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1608325200000,
#      'daysToExpiration': 44,
#      'expirationType': 'R',
#      'lastTradingDay': 1608339600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -0.02,
#      'markPercentChange': -0.39,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}]},
#   '2021-01-15:72': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P2.5',
#      'description': 'GGAL Jan 15 2021 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.4,
#      'last': 0.08,
#      'mark': 0.2,
#      'bidSize': 0,
#      'askSize': 1341,
#      'bidAskSize': '0X1341',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.0,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1603121812207,
#      'quoteTimeInLong': 1604514046658,
#      'netChange': 0.08,
#      'volatility': 195.061,
#      'delta': -0.053,
#      'gamma': 0.018,
#      'theta': -0.005,
#      'vega': 0.003,
#      'rho': -0.001,
#      'openInterest': 1515,
#      'timeValue': 0.08,
#      'theoreticalOptionValue': 0.2,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 2197.14,
#      'markChange': 0.2,
#      'markPercentChange': 5614.29,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P5',
#      'description': 'GGAL Jan 15 2021 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.15,
#      'ask': 0.3,
#      'last': 0.25,
#      'mark': 0.22,
#      'bidSize': 855,
#      'askSize': 558,
#      'bidAskSize': '855X558',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.28,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604425650617,
#      'quoteTimeInLong': 1604515603529,
#      'netChange': -0.03,
#      'volatility': 84.896,
#      'delta': -0.138,
#      'gamma': 0.083,
#      'theta': -0.004,
#      'vega': 0.007,
#      'rho': -0.002,
#      'openInterest': 873,
#      'timeValue': 0.25,
#      'theoreticalOptionValue': 0.225,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -9.09,
#      'markChange': -0.05,
#      'markPercentChange': -18.18,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P7.5',
#      'description': 'GGAL Jan 15 2021 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 1.15,
#      'ask': 1.3,
#      'last': 1.25,
#      'mark': 1.23,
#      'bidSize': 409,
#      'askSize': 301,
#      'bidAskSize': '409X301',
#      'lastSize': 0,
#      'highPrice': 1.25,
#      'lowPrice': 1.25,
#      'openPrice': 0.0,
#      'closePrice': 1.21,
#      'totalVolume': 9,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604508288220,
#      'quoteTimeInLong': 1604515597659,
#      'netChange': 0.04,
#      'volatility': 75.229,
#      'delta': -0.509,
#      'gamma': 0.168,
#      'theta': -0.007,
#      'vega': 0.013,
#      'rho': -0.01,
#      'openInterest': 385,
#      'timeValue': 0.79,
#      'theoreticalOptionValue': 1.225,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 3.56,
#      'markChange': 0.02,
#      'markPercentChange': 1.49,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P10',
#      'description': 'GGAL Jan 15 2021 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 3.0,
#      'ask': 3.3,
#      'last': 3.11,
#      'mark': 3.15,
#      'bidSize': 531,
#      'askSize': 558,
#      'bidAskSize': '531X558',
#      'lastSize': 0,
#      'highPrice': 3.2,
#      'lowPrice': 3.11,
#      'openPrice': 0.0,
#      'closePrice': 3.13,
#      'totalVolume': 12,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604515043541,
#      'quoteTimeInLong': 1604515588666,
#      'netChange': -0.02,
#      'volatility': 70.919,
#      'delta': -0.828,
#      'gamma': 0.113,
#      'theta': -0.004,
#      'vega': 0.008,
#      'rho': -0.018,
#      'openInterest': 701,
#      'timeValue': 0.15,
#      'theoreticalOptionValue': 3.15,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -0.6,
#      'markChange': 0.02,
#      'markPercentChange': 0.67,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P12.5',
#      'description': 'GGAL Jan 15 2021 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 5.3,
#      'ask': 5.6,
#      'last': 5.53,
#      'mark': 5.45,
#      'bidSize': 601,
#      'askSize': 48,
#      'bidAskSize': '601X48',
#      'lastSize': 0,
#      'highPrice': 5.58,
#      'lowPrice': 5.52,
#      'openPrice': 0.0,
#      'closePrice': 5.48,
#      'totalVolume': 12,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604515043541,
#      'quoteTimeInLong': 1604515552634,
#      'netChange': 0.05,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.002,
#      'rho': 'NaN',
#      'openInterest': 2455,
#      'timeValue': 0.07,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.86,
#      'markChange': -0.03,
#      'markPercentChange': -0.6,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P15',
#      'description': 'GGAL Jan 15 2021 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 7.8,
#      'ask': 8.2,
#      'last': 7.8,
#      'mark': 8.0,
#      'bidSize': 430,
#      'askSize': 421,
#      'bidAskSize': '430X421',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 7.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1602179741468,
#      'quoteTimeInLong': 1604515360660,
#      'netChange': -0.27,
#      'volatility': 69.123,
#      'delta': -0.987,
#      'gamma': 0.013,
#      'theta': -0.001,
#      'vega': 0.001,
#      'rho': -0.03,
#      'openInterest': 4981,
#      'timeValue': -0.16,
#      'theoreticalOptionValue': 8.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -3.37,
#      'markChange': 0.05,
#      'markPercentChange': 0.6,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '17.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P17.5',
#      'description': 'GGAL Jan 15 2021 17.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 10.2,
#      'ask': 10.9,
#      'last': 10.45,
#      'mark': 10.55,
#      'bidSize': 221,
#      'askSize': 94,
#      'bidAskSize': '221X94',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 10.45,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1601404213947,
#      'quoteTimeInLong': 1604515583468,
#      'netChange': 0.0,
#      'volatility': 113.211,
#      'delta': -0.937,
#      'gamma': 0.034,
#      'theta': -0.003,
#      'vega': 0.004,
#      'rho': -0.034,
#      'openInterest': 54,
#      'timeValue': -0.01,
#      'theoreticalOptionValue': 10.55,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.1,
#      'markPercentChange': 0.96,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '20.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P20',
#      'description': 'GGAL Jan 15 2021 20 Put',
#      'exchangeName': 'OPR',
#      'bid': 12.8,
#      'ask': 13.1,
#      'last': 13.04,
#      'mark': 12.95,
#      'bidSize': 246,
#      'askSize': 57,
#      'bidAskSize': '246X57',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 12.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1586451400838,
#      'quoteTimeInLong': 1604515584888,
#      'netChange': -0.02,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.001,
#      'rho': 'NaN',
#      'openInterest': 111,
#      'timeValue': 0.08,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -0.15,
#      'markChange': 0.0,
#      'markPercentChange': 0.0,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '22.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P22.5',
#      'description': 'GGAL Jan 15 2021 22.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 15.2,
#      'ask': 15.6,
#      'last': 15.6,
#      'mark': 15.4,
#      'bidSize': 103,
#      'askSize': 52,
#      'bidAskSize': '103X52',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 15.45,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1587565203738,
#      'quoteTimeInLong': 1604515584707,
#      'netChange': 0.04,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.001,
#      'rho': 'NaN',
#      'openInterest': 0,
#      'timeValue': 0.14,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 22.5,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.26,
#      'markChange': -0.05,
#      'markPercentChange': -0.32,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '25.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P25',
#      'description': 'GGAL Jan 15 2021 25 Put',
#      'exchangeName': 'OPR',
#      'bid': 17.7,
#      'ask': 18.3,
#      'last': 15.8,
#      'mark': 18.0,
#      'bidSize': 127,
#      'askSize': 82,
#      'bidAskSize': '127X82',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 17.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1600098317201,
#      'quoteTimeInLong': 1604515570534,
#      'netChange': -2.15,
#      'volatility': 118.82,
#      'delta': -0.981,
#      'gamma': 0.011,
#      'theta': -0.001,
#      'vega': 0.001,
#      'rho': -0.05,
#      'openInterest': 14,
#      'timeValue': -2.16,
#      'theoreticalOptionValue': 18.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 25.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -11.98,
#      'markChange': 0.05,
#      'markPercentChange': 0.28,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '30.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P30',
#      'description': 'GGAL Jan 15 2021 30 Put',
#      'exchangeName': 'OPR',
#      'bid': 22.6,
#      'ask': 23.2,
#      'last': 19.8,
#      'mark': 22.9,
#      'bidSize': 149,
#      'askSize': 64,
#      'bidAskSize': '149X64',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 22.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1599757140701,
#      'quoteTimeInLong': 1604515569421,
#      'netChange': -3.26,
#      'volatility': 'NaN',
#      'delta': 'NaN',
#      'gamma': 'NaN',
#      'theta': 'NaN',
#      'vega': 0.001,
#      'rho': 'NaN',
#      'openInterest': 0,
#      'timeValue': -3.16,
#      'theoreticalOptionValue': 'NaN',
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 30.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -14.2,
#      'markChange': -0.05,
#      'markPercentChange': -0.22,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '35.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P35',
#      'description': 'GGAL Jan 15 2021 35 Put',
#      'exchangeName': 'OPR',
#      'bid': 27.7,
#      'ask': 28.3,
#      'last': 24.8,
#      'mark': 28.0,
#      'bidSize': 136,
#      'askSize': 91,
#      'bidAskSize': '136X91',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 27.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1599757140701,
#      'quoteTimeInLong': 1604515520852,
#      'netChange': -3.15,
#      'volatility': 145.203,
#      'delta': -0.982,
#      'gamma': 0.009,
#      'theta': -0.001,
#      'vega': 0.001,
#      'rho': -0.069,
#      'openInterest': 0,
#      'timeValue': -3.16,
#      'theoreticalOptionValue': 28.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 35.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -11.27,
#      'markChange': 0.05,
#      'markPercentChange': 0.18,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '40.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P40',
#      'description': 'GGAL Jan 15 2021 40 Put',
#      'exchangeName': 'OPR',
#      'bid': 32.7,
#      'ask': 33.4,
#      'last': 33.99,
#      'mark': 33.05,
#      'bidSize': 122,
#      'askSize': 100,
#      'bidAskSize': '122X100',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 32.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1584632463788,
#      'quoteTimeInLong': 1604515583473,
#      'netChange': 1.04,
#      'volatility': 184.711,
#      'delta': -0.953,
#      'gamma': 0.016,
#      'theta': -0.004,
#      'vega': 0.003,
#      'rho': -0.099,
#      'openInterest': 0,
#      'timeValue': 1.03,
#      'theoreticalOptionValue': 33.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 40.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 3.16,
#      'markChange': 0.1,
#      'markPercentChange': 0.3,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '45.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P45',
#      'description': 'GGAL Jan 15 2021 45 Put',
#      'exchangeName': 'OPR',
#      'bid': 37.8,
#      'ask': 38.3,
#      'last': 19.5,
#      'mark': 38.05,
#      'bidSize': 104,
#      'askSize': 80,
#      'bidAskSize': '104X80',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 37.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1558622312234,
#      'quoteTimeInLong': 1604515570534,
#      'netChange': -18.56,
#      'volatility': 191.002,
#      'delta': -0.957,
#      'gamma': 0.014,
#      'theta': -0.004,
#      'vega': 0.003,
#      'rho': -0.148,
#      'openInterest': 0,
#      'timeValue': -18.46,
#      'theoreticalOptionValue': 38.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 45.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -48.91,
#      'markChange': 0.1,
#      'markPercentChange': 0.26,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '50.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_011521P50',
#      'description': 'GGAL Jan 15 2021 50 Put',
#      'exchangeName': 'OPR',
#      'bid': 42.7,
#      'ask': 43.4,
#      'last': 0.0,
#      'mark': 43.05,
#      'bidSize': 125,
#      'askSize': 95,
#      'bidAskSize': '125X95',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 42.95,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515583468,
#      'netChange': 0.0,
#      'volatility': 203.52,
#      'delta': -0.952,
#      'gamma': 0.014,
#      'theta': -0.004,
#      'vega': 0.003,
#      'rho': -0.31,
#      'openInterest': 0,
#      'timeValue': 0.09,
#      'theoreticalOptionValue': 43.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 50.0,
#      'expirationDate': 1610744400000,
#      'daysToExpiration': 72,
#      'expirationType': 'R',
#      'lastTradingDay': 1610758800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.1,
#      'markPercentChange': 0.23,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}]},
#   '2021-04-16:163': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P2.5',
#      'description': 'GGAL Apr 16 2021 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.1,
#      'last': 0.05,
#      'mark': 0.05,
#      'bidSize': 0,
#      'askSize': 3,
#      'bidAskSize': '0X3',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.03,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1598022342104,
#      'quoteTimeInLong': 1604510434495,
#      'netChange': -0.12,
#      'volatility': 92.112,
#      'delta': -0.024,
#      'gamma': 0.013,
#      'theta': -0.001,
#      'vega': 0.003,
#      'rho': -0.001,
#      'openInterest': 3,
#      'timeValue': 0.05,
#      'theoreticalOptionValue': 0.05,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -395.57,
#      'markChange': 0.02,
#      'markPercentChange': 58.23,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P5',
#      'description': 'GGAL Apr 16 2021 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.45,
#      'ask': 0.6,
#      'last': 0.74,
#      'mark': 0.53,
#      'bidSize': 525,
#      'askSize': 214,
#      'bidAskSize': '525X214',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.55,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1603997889027,
#      'quoteTimeInLong': 1604515603529,
#      'netChange': 0.19,
#      'volatility': 82.008,
#      'delta': -0.186,
#      'gamma': 0.069,
#      'theta': -0.003,
#      'vega': 0.013,
#      'rho': -0.008,
#      'openInterest': 71,
#      'timeValue': 0.74,
#      'theoreticalOptionValue': 0.525,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 34.55,
#      'markChange': -0.03,
#      'markPercentChange': -4.55,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P7.5',
#      'description': 'GGAL Apr 16 2021 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 1.6,
#      'ask': 1.8,
#      'last': 1.68,
#      'mark': 1.7,
#      'bidSize': 526,
#      'askSize': 371,
#      'bidAskSize': '526X371',
#      'lastSize': 0,
#      'highPrice': 1.72,
#      'lowPrice': 1.65,
#      'openPrice': 0.0,
#      'closePrice': 1.67,
#      'totalVolume': 12,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604515043541,
#      'quoteTimeInLong': 1604515583468,
#      'netChange': 0.0,
#      'volatility': 75.13,
#      'delta': -0.451,
#      'gamma': 0.111,
#      'theta': -0.004,
#      'vega': 0.019,
#      'rho': -0.022,
#      'openInterest': 730,
#      'timeValue': 1.22,
#      'theoreticalOptionValue': 1.7,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.3,
#      'markChange': 0.03,
#      'markPercentChange': 1.49,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '10.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P10',
#      'description': 'GGAL Apr 16 2021 10 Put',
#      'exchangeName': 'OPR',
#      'bid': 3.4,
#      'ask': 3.6,
#      'last': 3.5,
#      'mark': 3.5,
#      'bidSize': 418,
#      'askSize': 97,
#      'bidAskSize': '418X97',
#      'lastSize': 0,
#      'highPrice': 3.5,
#      'lowPrice': 3.43,
#      'openPrice': 0.0,
#      'closePrice': 3.47,
#      'totalVolume': 12,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604515043541,
#      'quoteTimeInLong': 1604515583464,
#      'netChange': 0.03,
#      'volatility': 70.558,
#      'delta': -0.693,
#      'gamma': 0.104,
#      'theta': -0.004,
#      'vega': 0.016,
#      'rho': -0.038,
#      'openInterest': 160,
#      'timeValue': 0.54,
#      'theoreticalOptionValue': 3.5,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.73,
#      'markChange': 0.03,
#      'markPercentChange': 0.73,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '12.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P12.5',
#      'description': 'GGAL Apr 16 2021 12.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 5.6,
#      'ask': 5.8,
#      'last': 0.0,
#      'mark': 5.7,
#      'bidSize': 42,
#      'askSize': 23,
#      'bidAskSize': '42X23',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 5.66,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515585285,
#      'netChange': 0.0,
#      'volatility': 68.615,
#      'delta': -0.844,
#      'gamma': 0.072,
#      'theta': -0.002,
#      'vega': 0.011,
#      'rho': -0.052,
#      'openInterest': 0,
#      'timeValue': 0.24,
#      'theoreticalOptionValue': 5.7,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.04,
#      'markPercentChange': 0.74,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '15.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P15',
#      'description': 'GGAL Apr 16 2021 15 Put',
#      'exchangeName': 'OPR',
#      'bid': 7.9,
#      'ask': 8.3,
#      'last': 8.15,
#      'mark': 8.1,
#      'bidSize': 340,
#      'askSize': 330,
#      'bidAskSize': '340X330',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 8.04,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1600874845282,
#      'quoteTimeInLong': 1604515489771,
#      'netChange': -0.03,
#      'volatility': 71.995,
#      'delta': -0.904,
#      'gamma': 0.048,
#      'theta': -0.002,
#      'vega': 0.008,
#      'rho': -0.065,
#      'openInterest': 60,
#      'timeValue': 0.19,
#      'theoreticalOptionValue': 8.1,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -0.35,
#      'markChange': 0.06,
#      'markPercentChange': 0.76,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '17.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P17.5',
#      'description': 'GGAL Apr 16 2021 17.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 10.3,
#      'ask': 10.7,
#      'last': 0.0,
#      'mark': 10.5,
#      'bidSize': 91,
#      'askSize': 62,
#      'bidAskSize': '91X62',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 10.48,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515571565,
#      'netChange': 0.0,
#      'volatility': 47.514,
#      'delta': -0.992,
#      'gamma': 0.004,
#      'theta': 0.0,
#      'vega': 0.0,
#      'rho': -0.078,
#      'openInterest': 0,
#      'timeValue': 0.04,
#      'theoreticalOptionValue': 10.5,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.02,
#      'markPercentChange': 0.2,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '20.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_041621P20',
#      'description': 'GGAL Apr 16 2021 20 Put',
#      'exchangeName': 'OPR',
#      'bid': 12.8,
#      'ask': 13.2,
#      'last': 0.0,
#      'mark': 13.0,
#      'bidSize': 98,
#      'askSize': 84,
#      'bidAskSize': '98X84',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 12.96,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604515611029,
#      'netChange': 0.0,
#      'volatility': 64.837,
#      'delta': -0.981,
#      'gamma': 0.012,
#      'theta': 0.0,
#      'vega': 0.002,
#      'rho': -0.089,
#      'openInterest': 0,
#      'timeValue': 0.04,
#      'theoreticalOptionValue': 13.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1618603200000,
#      'daysToExpiration': 163,
#      'expirationType': 'R',
#      'lastTradingDay': 1618617600000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': 0.04,
#      'markPercentChange': 0.33,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}]},
#   '2022-01-21:443': {'2.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P2.5',
#      'description': 'GGAL Jan 21 2022 2.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.2,
#      'ask': 0.4,
#      'last': 0.35,
#      'mark': 0.3,
#      'bidSize': 227,
#      'askSize': 339,
#      'bidAskSize': '227X339',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.38,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1601996346960,
#      'quoteTimeInLong': 1604515542843,
#      'netChange': 0.0,
#      'volatility': 89.924,
#      'delta': -0.063,
#      'gamma': 0.018,
#      'theta': -0.001,
#      'vega': 0.01,
#      'rho': -0.009,
#      'openInterest': 599,
#      'timeValue': 0.35,
#      'theoreticalOptionValue': 0.3,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -0.08,
#      'markPercentChange': -21.28,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '5.0': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P5',
#      'description': 'GGAL Jan 21 2022 5 Put',
#      'exchangeName': 'OPR',
#      'bid': 0.9,
#      'ask': 1.4,
#      'last': 1.2,
#      'mark': 1.15,
#      'bidSize': 1058,
#      'askSize': 546,
#      'bidAskSize': '1058X546',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.29,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604431333771,
#      'quoteTimeInLong': 1604515590659,
#      'netChange': 0.0,
#      'volatility': 78.203,
#      'delta': -0.205,
#      'gamma': 0.047,
#      'theta': -0.002,
#      'vega': 0.022,
#      'rho': -0.032,
#      'openInterest': 319,
#      'timeValue': 1.2,
#      'theoreticalOptionValue': 1.15,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -1.14,
#      'markPercentChange': -49.89,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '7.5': [{'putCall': 'PUT',
#      'symbol': 'GGAL_012122P7.5',
#      'description': 'GGAL Jan 21 2022 7.5 Put',
#      'exchangeName': 'OPR',
#      'bid': 2.25,
#      'ask': 3.1,
#      'last': 2.75,
#      'mark': 2.68,
#      'bidSize': 1050,
#      'askSize': 1006,
#      'bidAskSize': '1050X1006',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 4.21,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604431274190,
#      'quoteTimeInLong': 1604515621422,
#      'netChange': -1.46,
#      'volatility': 77.675,
#      'delta': -0.362,
#      'gamma': 0.062,
#      'theta': -0.003,
#      'vega': 0.029,
#      'rho': -0.063,
#      'openInterest': 217,
#      'timeValue': 2.29,
#      'theoreticalOptionValue': 2.675,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
# ...
#      'quoteTimeInLong': 1604515432192,
#      'netChange': 0.25,
#      'volatility': 69.549,
#      'delta': 0.347,
#      'gamma': 0.068,
#      'theta': -0.002,
#      'vega': 0.028,
#      'rho': 0.018,
#      'openInterest': 203,
#      'timeValue': 1.0,
#      'theoreticalOptionValue': 0.875,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 19.63,
#      'markChange': -0.4,
#      'markPercentChange': -31.3,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '15.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C15',
#      'description': 'GGAL Jan 21 2022 15 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.3,
#      'ask': 0.95,
#      'last': 0.65,
#      'mark': 0.63,
#      'bidSize': 1058,
#      'askSize': 841,
#      'bidAskSize': '1058X841',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.9,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604418242647,
#      'quoteTimeInLong': 1604515572171,
#      'netChange': 0.1,
#      'volatility': 69.889,
#      'delta': 0.266,
#      'gamma': 0.06,
#      'theta': -0.002,
#      'vega': 0.025,
#      'rho': 0.015,
#      'openInterest': 426,
#      'timeValue': 0.65,
#      'theoreticalOptionValue': 0.625,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 11.49,
#      'markChange': -0.27,
#      'markPercentChange': -30.42,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '17.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C17.5',
#      'description': 'GGAL Jan 21 2022 17.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.35,
#      'ask': 0.6,
#      'last': 0.65,
#      'mark': 0.48,
#      'bidSize': 170,
#      'askSize': 349,
#      'bidAskSize': '170X349',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.54,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1600788799288,
#      'quoteTimeInLong': 1604515571224,
#      'netChange': 0.11,
#      'volatility': 70.876,
#      'delta': 0.211,
#      'gamma': 0.052,
#      'theta': -0.002,
#      'vega': 0.022,
#      'rho': 0.012,
#      'openInterest': 10,
#      'timeValue': 0.65,
#      'theoreticalOptionValue': 0.475,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 21.38,
#      'markChange': -0.06,
#      'markPercentChange': -11.3,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '20.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C20',
#      'description': 'GGAL Jan 21 2022 20 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.15,
#      'ask': 0.5,
#      'last': 0.2,
#      'mark': 0.33,
#      'bidSize': 553,
#      'askSize': 492,
#      'bidAskSize': '553X492',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.44,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1603741400515,
#      'quoteTimeInLong': 1604515618213,
#      'netChange': -0.24,
#      'volatility': 69.267,
#      'delta': 0.156,
#      'gamma': 0.044,
#      'theta': -0.001,
#      'vega': 0.019,
#      'rho': 0.009,
#      'openInterest': 757,
#      'timeValue': 0.2,
#      'theoreticalOptionValue': 0.325,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -54.15,
#      'markChange': -0.11,
#      'markPercentChange': -25.49,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '22.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012122C22.5',
#      'description': 'GGAL Jan 21 2022 22.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 0.35,
#      'last': 0.3,
#      'mark': 0.18,
#      'bidSize': 0,
#      'askSize': 342,
#      'bidAskSize': '0X342',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.35,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604416972118,
#      'quoteTimeInLong': 1604515322706,
#      'netChange': -0.05,
#      'volatility': 64.399,
#      'delta': 0.096,
#      'gamma': 0.034,
#      'theta': -0.001,
#      'vega': 0.013,
#      'rho': 0.006,
#      'openInterest': 489,
#      'timeValue': 0.3,
#      'theoreticalOptionValue': 0.175,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 22.5,
#      'expirationDate': 1642798800000,
#      'daysToExpiration': 443,
#      'expirationType': 'R',
#      'lastTradingDay': 1642813200000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -14.41,
#      'markChange': -0.18,
#      'markPercentChange': -50.07,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}]},
#   '2023-01-20:807': {'2.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C2.5',
#      'description': 'GGAL Jan 20 2023 2.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 2.5,
#      'ask': 7.5,
#      'last': 0.0,
#      'mark': 5.0,
#      'bidSize': 1,
#      'askSize': 1,
#      'bidAskSize': '1X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 6.52,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 0,
#      'quoteTimeInLong': 1604503792613,
#      'netChange': 0.0,
#      'volatility': 98.725,
#      'delta': 0.841,
#      'gamma': 0.007,
#      'theta': -0.001,
#      'vega': 0.012,
#      'rho': 0.012,
#      'openInterest': 0,
#      'timeValue': 0.46,
#      'theoreticalOptionValue': 5.0,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 2.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 0.0,
#      'markChange': -1.52,
#      'markPercentChange': -23.26,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '5.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C5',
#      'description': 'GGAL Jan 20 2023 5 Call',
#      'exchangeName': 'OPR',
#      'bid': 1.25,
#      'ask': 5.9,
#      'last': 3.6,
#      'mark': 3.58,
#      'bidSize': 278,
#      'askSize': 172,
#      'bidAskSize': '278X172',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 4.35,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1602601093016,
#      'quoteTimeInLong': 1604515584502,
#      'netChange': -0.75,
#      'volatility': 77.825,
#      'delta': 0.765,
#      'gamma': 0.028,
#      'theta': -0.001,
#      'vega': 0.026,
#      'rho': 0.03,
#      'openInterest': 200,
#      'timeValue': 1.56,
#      'theoreticalOptionValue': 3.575,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 5.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -17.33,
#      'markChange': -0.78,
#      'markPercentChange': -17.9,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': True}],
#    '7.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C7.5',
#      'description': 'GGAL Jan 20 2023 7.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 2.55,
#      'ask': 3.2,
#      'last': 2.55,
#      'mark': 2.88,
#      'bidSize': 10,
#      'askSize': 27,
#      'bidAskSize': '10X27',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 2.49,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1602270707518,
#      'quoteTimeInLong': 1604515388015,
#      'netChange': 0.06,
#      'volatility': 79.406,
#      'delta': 0.671,
#      'gamma': 0.038,
#      'theta': -0.002,
#      'vega': 0.034,
#      'rho': 0.034,
#      'openInterest': 2,
#      'timeValue': 2.55,
#      'theoreticalOptionValue': 2.875,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 7.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 2.44,
#      'markChange': 0.39,
#      'markPercentChange': 15.5,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '10.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C10',
#      'description': 'GGAL Jan 20 2023 10 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.3,
#      'ask': 4.3,
#      'last': 1.95,
#      'mark': 2.3,
#      'bidSize': 167,
#      'askSize': 210,
#      'bidAskSize': '167X210',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.63,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604426270423,
#      'quoteTimeInLong': 1604515451861,
#      'netChange': -0.02,
#      'volatility': 77.985,
#      'delta': 0.583,
#      'gamma': 0.044,
#      'theta': -0.002,
#      'vega': 0.039,
#      'rho': 0.036,
#      'openInterest': 26,
#      'timeValue': 1.95,
#      'theoreticalOptionValue': 2.3,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 10.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': -0.97,
#      'markChange': 0.67,
#      'markPercentChange': 41.38,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '12.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C12.5',
#      'description': 'GGAL Jan 20 2023 12.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.2,
#      'ask': 4.1,
#      'last': 1.61,
#      'mark': 2.15,
#      'bidSize': 159,
#      'askSize': 190,
#      'bidAskSize': '159X190',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 1.08,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604425216039,
#      'quoteTimeInLong': 1604515514608,
#      'netChange': 0.41,
#      'volatility': 84.068,
#      'delta': 0.542,
#      'gamma': 0.042,
#      'theta': -0.002,
#      'vega': 0.04,
#      'rho': 0.033,
#      'openInterest': 4,
#      'timeValue': 1.61,
#      'theoreticalOptionValue': 2.15,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 12.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 38.26,
#      'markChange': 1.07,
#      'markPercentChange': 98.49,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '15.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C15',
#      'description': 'GGAL Jan 20 2023 15 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 3.7,
#      'last': 1.45,
#      'mark': 1.85,
#      'bidSize': 0,
#      'askSize': 183,
#      'bidAskSize': '0X183',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.74,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1600976768755,
#      'quoteTimeInLong': 1604515622651,
#      'netChange': 0.71,
#      'volatility': 84.031,
#      'delta': 0.486,
#      'gamma': 0.043,
#      'theta': -0.002,
#      'vega': 0.04,
#      'rho': 0.032,
#      'openInterest': 1,
#      'timeValue': 1.45,
#      'theoreticalOptionValue': 1.85,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 15.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 97.2,
#      'markChange': 1.11,
#      'markPercentChange': 151.6,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '17.5': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C17.5',
#      'description': 'GGAL Jan 20 2023 17.5 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 1.0,
#      'last': 0.7,
#      'mark': 0.5,
#      'bidSize': 0,
#      'askSize': 1,
#      'bidAskSize': '0X1',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.51,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1604332628900,
#      'quoteTimeInLong': 1604515349475,
#      'netChange': 0.07,
#      'volatility': 53.946,
#      'delta': 0.217,
#      'gamma': 0.052,
#      'theta': -0.001,
#      'vega': 0.03,
#      'rho': 0.022,
#      'openInterest': 41,
#      'timeValue': 0.7,
#      'theoreticalOptionValue': 0.5,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 17.5,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 14.49,
#      'markChange': -0.01,
#      'markPercentChange': -1.69,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}],
#    '20.0': [{'putCall': 'CALL',
#      'symbol': 'GGAL_012023C20',
#      'description': 'GGAL Jan 20 2023 20 Call',
#      'exchangeName': 'OPR',
#      'bid': 0.0,
#      'ask': 1.65,
#      'last': 0.55,
#      'mark': 0.83,
#      'bidSize': 0,
#      'askSize': 203,
#      'bidAskSize': '0X203',
#      'lastSize': 0,
#      'highPrice': 0.0,
#      'lowPrice': 0.0,
#      'openPrice': 0.0,
#      'closePrice': 0.36,
#      'totalVolume': 0,
#      'tradeDate': None,
#      'tradeTimeInLong': 1603466143848,
#      'quoteTimeInLong': 1604515409401,
#      'netChange': 0.07,
#      'volatility': 68.183,
#      'delta': 0.286,
#      'gamma': 0.047,
#      'theta': -0.001,
#      'vega': 0.035,
#      'rho': 0.025,
#      'openInterest': 9,
#      'timeValue': 0.55,
#      'theoreticalOptionValue': 0.825,
#      'theoreticalVolatility': 29.0,
#      'optionDeliverablesList': None,
#      'strikePrice': 20.0,
#      'expirationDate': 1674248400000,
#      'daysToExpiration': 807,
#      'expirationType': 'R',
#      'lastTradingDay': 1674262800000,
#      'multiplier': 100.0,
#      'settlementType': ' ',
#      'deliverableNote': '',
#      'isIndexOption': None,
#      'percentChange': 19.16,
#      'markChange': 0.47,
#      'markPercentChange': 130.45,
#      'mini': False,
#      'nonStandard': False,
#      'inTheMoney': False}]}}}

# %% [markdown]
# ## Metemos el OptionChain en un DataFrame

# %%
ticker = 'AAPL'
chain = options(ticker)

v_calls = list(chain['callExpDateMap'].values())
v_calls_fechas = list(chain['callExpDateMap'].keys())
v_puts = list(chain['putExpDateMap'].values())
v_puts_fechas = list(chain['putExpDateMap'].keys())
calls = []
for i in range(len(v_calls)):
    v = list(v_calls[i].values())    
    for j in range(len(v)):
        calls.append(v[j][0])

puts = []
for i in range(len(v_puts)):
    v = list(v_puts[i].values())    
    for j in range(len(v)):
        puts.append(v[j][0])
        
contracts = pd.concat([pd.DataFrame(calls),pd.DataFrame(puts)])

tabla = contracts.loc[contracts.daysToExpiration>0]
tabla = tabla.loc[:,['symbol','strikePrice','daysToExpiration','putCall','bid','ask',
                     'last','volatility','openInterest','theoreticalOptionValue',
                     'delta', 'gamma', 'theta', 'vega', 'rho', 'inTheMoney']]

tabla.columns = ['symbol_opc','Strike','TTM','Type','Bid','Ask','Last','IV','OpenInt','Theor',
                 'delta', 'gamma', 'theta', 'vega', 'rho','ITM']

tabla['symbol'] = ticker
tabla
# Out:
#            symbol_opc  Strike  TTM  Type     Bid     Ask    Last      IV  \
# 0      AAPL_110620C60    60.0    2  CALL   54.90   55.00   55.00     NaN
# 1      AAPL_110620C65    65.0    2  CALL   49.90   50.00   50.24     NaN
# 2      AAPL_110620C70    70.0    2  CALL   44.90   45.00   45.31     NaN
# 3      AAPL_110620C71    71.0    2  CALL   43.90   44.00   39.15     NaN
# 4      AAPL_110620C72    72.0    2  CALL   42.90   43.00   36.75     NaN
# ...               ...     ...  ...   ...     ...     ...     ...     ...
# 1232  AAPL_012023P190   190.0  807   PUT   80.20   81.80   80.05   31.36
# 1233  AAPL_012023P195   195.0  807   PUT   84.70   86.35   85.35  31.426
# 1234  AAPL_012023P200   200.0  807   PUT   89.25   90.95   96.05  31.365
# 1235  AAPL_012023P210   210.0  807   PUT   98.50  100.15  105.35   30.94
# 1236  AAPL_012023P220   220.0  807   PUT  107.75  109.60  109.16  30.618
#
#       OpenInt    Theor  delta  gamma  theta   vega    rho   ITM symbol
# 0         174      NaN    NaN    NaN    NaN  0.009    NaN  True   AAPL
# 1         127      NaN    NaN    NaN    NaN  0.009    NaN  True   AAPL
# 2          27      NaN    NaN    NaN    NaN  0.010    NaN  True   AAPL
# 3           1      NaN    NaN    NaN    NaN  0.010    NaN  True   AAPL
# 4          28      NaN    NaN    NaN    NaN  0.010    NaN  True   AAPL
# ...       ...      ...    ...    ...    ...    ...    ...   ...    ...
# 1232        1       81 -0.796  0.005  -0.01  0.458 -3.816  True   AAPL
# 1233        1   85.525  -0.81  0.005  -0.01  0.438 -3.951  True   AAPL
# 1234       10     90.1 -0.824  0.005 -0.009  0.415 -4.088  True   AAPL
# 1235       11   99.325 -0.853  0.004 -0.008  0.363 -4.365  True   AAPL
# 1236       60  108.675 -0.876  0.004 -0.007  0.316 -4.631  True   AAPL
#
# [2474 rows x 17 columns]

# %% [markdown]
# ## Encapsulamos el DF en una función

# %%
def optionsDF(chain):
    try:
        v_calls = list(chain['callExpDateMap'].values())
        v_calls_fechas = list(chain['callExpDateMap'].keys())
        v_puts = list(chain['putExpDateMap'].values())
        v_puts_fechas = list(chain['putExpDateMap'].keys())
        calls = []
        for i in range(len(v_calls)):
            v = list(v_calls[i].values())    
            for j in range(len(v)):
                calls.append(v[j][0])

        puts = []
        for i in range(len(v_puts)):
            v = list(v_puts[i].values())    
            for j in range(len(v)):
                puts.append(v[j][0])

        contracts = pd.concat([pd.DataFrame(calls),pd.DataFrame(puts)])
        tabla = contracts.loc[contracts.daysToExpiration>0]
        tabla = tabla.loc[:,['symbol','strikePrice','daysToExpiration','putCall','bid','ask',
                             'last','volatility','openInterest','theoreticalOptionValue',
                             'delta', 'gamma', 'theta', 'vega', 'rho', 'inTheMoney']]

        tabla.columns = ['symbol_opc','Strike','TTM','Type','Bid','Ask','Last','IV','OpenInt','Theor',
                         'delta', 'gamma', 'theta', 'vega', 'rho','ITM']

        tabla['symbol'] = chain['symbol']
    except:
        tabla = pd.DataFrame()
        
    return tabla

# %%
ticker = 'FB'
df = optionsDF(options(ticker))
df
# Out:
#          symbol_opc  Strike  TTM  Type     Bid     Ask    Last       IV  \
# 0     FB_110620C135   135.0    2  CALL  152.30  153.15  145.65      NaN
# 1     FB_110620C140   140.0    2  CALL  147.20  148.15  123.65      NaN
# 2     FB_110620C145   145.0    2  CALL  142.25  143.10  119.85   223.44
# 3     FB_110620C150   150.0    2  CALL  137.20  138.15  136.37  212.719
# 4     FB_110620C155   155.0    2  CALL  132.30  133.05  109.85  202.356
# ...             ...     ...  ...   ...     ...     ...     ...      ...
# 1204  FB_012023P480   480.0  807   PUT  201.60  205.90  210.49    33.87
# 1205  FB_012023P500   500.0  807   PUT  219.10  222.70  226.47   33.663
# 1206  FB_012023P520   520.0  807   PUT  237.05  241.45    0.00   34.405
# 1207  FB_012023P540   540.0  807   PUT  255.50  259.90  264.95   35.231
# 1208  FB_012023P560   560.0  807   PUT  274.60  278.80  277.90   36.481
#
#       OpenInt    Theor  delta  gamma  theta   vega    rho   ITM symbol
# 0          22      NaN    NaN    NaN    NaN  0.001    NaN  True     FB
# 1           7      NaN    NaN    NaN    NaN  0.001    NaN  True     FB
# 2          13  142.675      1      0 -0.009  0.000  0.012  True     FB
# 3          12  137.675      1      0 -0.009  0.000  0.012  True     FB
# 4          12  132.675      1      0 -0.009  0.000  0.013  True     FB
# ...       ...      ...    ...    ...    ...    ...    ...   ...    ...
# 1204        6   203.75 -0.735  0.001 -0.025  1.236 -4.992  True     FB
# 1205       15    220.9 -0.752  0.001 -0.024  1.158 -4.788  True     FB
# 1206        0   239.25 -0.756  0.001 -0.023  1.117 -4.628  True     FB
# 1207        5    257.7 -0.756  0.001 -0.023  1.086 -4.459  True     FB
# 1208      105    276.7 -0.752  0.001 -0.024  1.073 -4.336  True     FB
#
# [2418 rows x 17 columns]

# %% [markdown]
# ## Bckp opciones sp500 en la BBDD (Threading)

# %%
tickers = pd.read_sql('SELECT symbol FROM sp500_tickers', conn).symbol.tolist()
n_threads = 2
subs = np.array_split(tickers, n_threads)

# %%
# %%time

dfs = []
def worker(tickers):
    for ticker in tickers:
        print(ticker, end=' ')
        df = optionsDF(options(ticker))
        dfs.append(df)
        df.to_sql('sp500_opciones', engine, if_exists='append')
    return df

    
t0 = time.time()
threads = []
for i in range(n_threads):
    t = threading.Thread(target=worker, args=(subs[i],))
    threads.append(t)
    t.start()
    
for t in threads:
    t.join()
    
result = pd.concat(dfs)
result
# Out:
# MMM INTU ISRG ABT ABBV IVZ IPGP ABMD IQV ACN IRM JKHY ATVI J JBHT ADBE SJM AMD JNJ AAP AES JCI AFL JPM A JNPR APD KSU AKAM K ALK KEY ALB KEYS ARE ALXN KMB KIM ALGN KMI ALLE KLAC LNT ALL GOOGL KHC GOOG KR LB MO LHX AMZN LH AMCR LRCX AEE AAL LW LVS AEP LEG AXP LDOS LEN AIG LLY AMT LNC AWK AMP LIN ABC LYV LKQ AME LMT AMGN L APH LOW ADI LUMN LYB ANSS ANTM MTB AON MRO AOS MPC APA MKTX AIV MAR AAPL MMC AMAT MLM MAS MA APTV ADM ANET MKC AJG MXIM AIZ MCD T MCK ATO ADSK MDT ADP MRK AZO MET AVB MTD AVY MGM BKR MCHP BLL BAC MU BK MSFT BAX MAA BDX MHK TAP BBY MDLZ BIO MNST MCO BIIB MS BLK MOS MSI BA MSCI MYL BKNG NDAQ NOV BWA BXP NTAP BSX NFLX BMY NWL AVGO NEM NWSA BR NWS NEE CHRW NLSN COG NKE CDNS NI CPB NSC COF CAH KMX NTRS NOC CCL CARR NLOK CTLT NCLH CAT NRG CBOE NUE CBRE NVDA CDW NVR ORLY CE OXY CNC ODFL CNP OMC CERN OKE CF ORCL SCHW OTIS CHTR PCAR PKG CVX PH PAYX CMG PAYC CB PYPL CHD CI PNR CINF PBCT CTAS CSCO PEP C PKI CFG PRGO CTXS PFE CLX PM CME PSX CMS PNW KO PXD PNC CTSH POOL CL PPG PPL CMCSA PFG PG CMA PGR CAG PLD CXO PRU COP PEG PSA ED PHM STZ PVH QRVO COO PWR CPRT QCOM GLW DGX CTVA RL COST RJF CCI RTX CSX O CMI REG CVS REGN DHI RF DHR RSG RMD DRI RHI DVA ROK ROL DE ROP DAL ROST XRAY RCL DVN DXCM FANG DLR SPGI DFS CRM DISCA DISCK SBAC SLB DISH STX DG SEE SRE DLTR NOW D SHW DPZ SPG DOV DOW SWKS DTE SLG SNA DUK SO DRE LUV DD SWK DXC SBUX EMN STT ETN STE EBAY SYK ECL SIVB SYF EIX EW SNPS SYY EA TMUS EMR TROW TTWO ETR TPR EOG TGT EFX EQIX TEL FTI TDY EQR ESS TFX EL TER ETSY TXN EVRG TXT ES RE TMO EXC TIF EXPE TJX EXPD TSCO EXR XOM TT FFIV TDG FB TRV FAST TFC FRT FDX TWTR FIS TYL FITB TSN FE FRC UDR FISV ULTA FLT FLIR FLS USB FMC UAA F UA FTNT FTV UNP FBHS UAL FOXA FOX UNH BEN FCX UPS GPS URI GRMN IT UHS UNM GD VFC GE GIS GM VLO GPC VAR GILD VTR VRSN GL VRSK GPN VZ GS VRTX GWW VIAC HAL V HBI HIG VNT VNO VMC HAS WRB WAB WMT HCA PEAK WBA HSIC DIS HSY HES WM HPE WAT WEC HLT WFC HFC WELL HOLX WST HD HON WDC WU HRL HST HWM WRK HPQ WY HUM WHR HBAN HII WMB IEX WLTW IDXX WYNN INFO XEL ITW XRX XLNX ILMN XYL YUM INCY IR INTC ZBRA ICE ZBH ZION IBM ZTS IP IPG IFF Wall time: 5min 58s
#           symbol_opc  Strike  TTM  Type    Bid    Ask   Last       IV  \
# 0    INTU_110620C165   165.0    2  CALL  177.6  181.6   0.00      NaN
# 1    INTU_110620C170   170.0    2  CALL  173.0  177.5   0.00        5
# 2    INTU_110620C175   175.0    2  CALL  168.2  172.7   0.00  540.577
# 3    INTU_110620C180   180.0    2  CALL  163.8  167.3   0.00  514.893
# 4    INTU_110620C185   185.0    2  CALL  158.3  162.8   0.00  484.083
# ..               ...     ...  ...   ...    ...    ...    ...      ...
# 192   IFF_012023P165   165.0  807   PUT   68.0   71.9   0.00   31.888
# 193   IFF_012023P170   170.0  807   PUT   72.4   76.3   0.00   31.843
# 194   IFF_012023P175   175.0  807   PUT   77.3   80.6  68.24   31.878
# 195   IFF_012023P180   180.0  807   PUT   81.7   85.7  72.27   31.936
# 196   IFF_012023P185   185.0  807   PUT   86.3   90.3   0.00   31.882
#
#      OpenInt   Theor  delta  gamma  theta   vega    rho   ITM symbol
# 0          0     NaN    NaN    NaN    NaN  0.036    NaN  True   INTU
# 1          0  175.25      1      0      0  0.088      0  True   INTU
# 2          0  170.45  0.886      0  -2.44  0.036  0.002  True   INTU
# 3          0  165.55  0.889      0 -3.507  0.037  0.002  True   INTU
# 4          0  160.55  0.891      0 -2.838  0.037  0.002  True   INTU
# ..       ...     ...    ...    ...    ...    ...    ...   ...    ...
# 192        0   69.85 -0.748  0.005 -0.014  0.416 -3.294  True    IFF
# 193        0   74.35 -0.764  0.005 -0.014  0.393 -3.433  True    IFF
# 194        3   78.95 -0.779  0.005 -0.013  0.372 -3.568  True    IFF
# 195        1    83.6 -0.792  0.004 -0.013  0.352 -3.702  True    IFF
# 196        0    88.3 -0.805  0.004 -0.013  0.330 -3.836  True    IFF
#
# [339112 rows x 17 columns]

# %% [markdown]
# ## Arreglo BUG

# %% [markdown]
# TDA algunas veces tira IV = -999

# %%
query = 'UPDATE sp500_opciones SET IV = NULL WHERE IV < 0'
r = engine.execute(query)

# %% [markdown]
# ## Agrego PK

# %%
q = 'ALTER TABLE sp500_opciones ADD id INT NOT NULL AUTO_INCREMENT PRIMARY KEY'
conn.execute(q)

# %%
q = 'ALTER TABLE sp500_opciones CHANGE IV IV FLOAT NULL DEFAULT NULL'
conn.execute(q)

# %% [markdown]
# # Intraday 1min Sigma

# %%
from clase_11_keys import *
iex_token = IEX_TOKEN

# %%
def iex_intraday(symbol):
    url = f'https://cloud.iexapis.com/stable/stock/{symbol}/intraday-prices'
    params = {'chartIEXOnly':True, 'token':iex_token }
    js = requests.get(url, params=params).json()
    df = pd.DataFrame(js)
    df.date = pd.to_datetime(df.date)
    df['symbol'] = symbol
    df['pctChange'] = df.average.pct_change()*100
    return df.dropna().round(3)

# %% [markdown]
# ## Descarga con hilos

# %%
tickers = pd.read_sql('SELECT symbol FROM sp500_tickers', conn).symbol.tolist()
n_threads = 40
subs = np.array_split(tickers, n_threads)

# %%
# %%time

dfs = []
def worker(tickers):
    for ticker in tickers:
        print(ticker, end=' ')
        df = iex_intraday(ticker)
        dfs.append(df)
    return df

    
t0 = time.time()
threads = []
for i in range(n_threads):
    t = threading.Thread(target=worker, args=(subs[i],))
    threads.append(t)
    t.start()
    
for t in threads:
    t.join()
    
result = pd.concat(dfs)
result
# Out:
# MMM AKAM AMCR ADI AIZ BDX CHRW CDW CINF CMACMI  DFS DD EQIX FFIV FMC GE HCA HWM ICE JBHT KLAC LNC MAR MTDMOS  NEE NVR PAYC PNC PVH RSG STX SBUX TGT TT UNP VRSKDIS  WMB ABTAEE  CVS ANSSALK FB  PYPL DXC CE DISCA LINPEAK  STT IBM T KHCMSI  CAG BBYTDGFVZ ORLY  GIS EQR  CTAS QRVO TEL  SEEHPQWM SJM  NLSN  COG UALMMC WLTWRMD   MGMPOOL  AAL ABBV FAST ANTM DISCK CNC PNR ALB EMN STE LYV MSCI JNJ HSIC BIOKRWYNN   DHI TRV MCHP IP FTNTMLM OXY  UNH PPGSRE  CSCOGM  FTI ESSCXOATO  RHI CDNSPWR  WAT  NKE HUM VRTX AEP ABMD AON FRT ARE ETN CNP SYKDISH  LKQ PBCT MYL JCI MU BIIB ODFL TFC HSY LBDHR  IPG WECNOW XEL  ELMAS TDYC   ROK QCOM PPLGPC  NI ADSK CPB UPS FTV COPVIAC  HBAN ACN AXP AOS ALXN FDX DG CERN LMT SIVB PEP EBAY NDAQ MSFT JPM OMC BLK HES TWTR DRI IFF LHX XRX WFC TFX SHW COF MA CFGROLPFG   GILD ETSYURI DGXADPFBHSHII     EDAIG  NSC V ATVI APA FIS ALGN DLTR ECL PKI CF NOVL  SYF MAA JNPR BA OKE TYL HPE INTU LH DVA WELL TER XLNX SPG PG RLCAH  CTXS IEX ROP MKCAZO  GL FOXA UHS STZ FITBAMT EVRG  NTRS AIVADBE  VNTALLE D  EIX PRGO SNPSSCHW  NTAP LOW KSU MHK ORCL BKNG TSN HLT ISRG DE LRCX WST TXN XYL SWKS PGR AVB RJF CLX IDXX UNM FE ROST AMD LNT COO GPNAWK  SYYMXIM  DPZAAPL NFLXEW   PFEVNO CHTR  KMXTAP FOX LUMN  OTIS K BWA UDR ES HFC IVZ DAL WDC LW SLG NOC YUM TXT PLD CME AVY RTX VFC INFO RCLAAP  ALL CVX PMRE  FRC EA AMAT HOLXCPRT  CCLDOV  VMC BXP MDLZ MCDULTA  AMP LYB NWL IPGP PCAR TMUS KEY WUBEN  LVS GS PRU NLOK XRAY TMOVLO  SNAO  ITWBKR  CMS SPGI ZBRA AES GOOGL EXC EMR CARR PSX DOWWRB  APTV FISV BSX HD GLW REG PNW CMG ABC TROW USB KEYSCTLT  PKG NEM KO DVN NCLH IQV GOOGFCX  TIF MTB WRK WAB ADM SO CTVA ILMN BMY PXD REGN AME CB TTWO UAA KMB BLLPEG  NWSA GWWVAR  CRM DXCM CTSH NRG FLT MO MRO HON EXPE IRM LUV PH CAT TJX ANET WMT GPS COST WY RF AMGN CHD TPR PSA UA KIM BAC NWS VTR AVGO SBAC CL FANG HRL FLIR AMZN MPC HAL NUE PAYX AJG SWK CBOE ZBHAFL  EXPD ETRJKHY  GRMN TSCO WBA CCI WHR INCY APH CI PHM BK KMI VRSN BR SLB FLS HST CMCSA DLR NVDA MKTX HBI CBREA  EOG ZION J CSX EXRIT  IR BAX HIG EFX GD APD ZTS INTC XOM HAS MNST MCK LEGDTE  MCO MDTDUK  LDOS DREMRK  LEN MS MET LLY Wall time: 23 s
#           date minute     label     high      low     open    close  average  \
# 1   2020-11-04  09:31  09:31 AM  162.910  162.790  162.880  162.910  162.850
# 2   2020-11-04  09:32  09:32 AM  163.135  162.790  162.790  163.135  163.025
# 3   2020-11-04  09:33  09:33 AM  162.840  162.580  162.810  162.580  162.757
# 4   2020-11-04  09:34  09:34 AM  162.740  162.460  162.510  162.740  162.485
# 5   2020-11-04  09:35  09:35 AM  162.240  161.875  162.240  161.875  161.934
# ..         ...    ...       ...      ...      ...      ...      ...      ...
# 265 2020-11-04  13:55   1:55 PM  150.400  150.340  150.400  150.360  150.385
# 266 2020-11-04  13:56   1:56 PM  150.410  150.140  150.405  150.140  150.296
# 267 2020-11-04  13:57   1:57 PM  150.310  150.160  150.175  150.160  150.210
# 268 2020-11-04  13:58   1:58 PM  150.060  149.960  150.040  150.060  150.037
# 269 2020-11-04  13:59   1:59 PM  150.120  149.880  150.120  149.885  150.032
#
#      volume    notional  numberOfTrades symbol  pctChange
# 1     764.0  124417.320             6.0    MMM     -0.368
# 2     927.0  151124.320            13.0    MMM      0.107
# 3    1075.0  174963.500            12.0    MMM     -0.164
# 4     310.0   50370.400             5.0    MMM     -0.167
# 5     850.0  137644.000             9.0    MMM     -0.339
# ..      ...         ...             ...    ...        ...
# 265   540.0   81207.900             5.0    LLY     -0.072
# 266   810.0  121739.435            11.0    LLY     -0.059
# 267  2168.0  325655.950            16.0    LLY     -0.057
# 268   992.0  148836.680             9.0    LLY     -0.115
# 269   461.0   69164.960             8.0    LLY     -0.003
#
# [111086 rows x 13 columns]

# %% [markdown]
# ## Guardado en BBDD

# %%
# %%time
result.to_sql('sp500_iex_intraday', conn, if_exists='replace')
# Out:
# Wall time: 6.78 s

# %%
q = 'ALTER TABLE sp500_iex_intraday ADD id INT NOT NULL AUTO_INCREMENT PRIMARY KEY'
conn.execute(q)

# %%
# %%time
q = '''SELECT symbol, STDDEV(pctChange) * SQRT(390*250) as sigma_intraday 
        FROM  sp500_iex_intraday
        GROUP BY symbol'''
pd.read_sql(q, conn)
# Out:
# Wall time: 258 ms
#     symbol  sigma_intraday
# 0        A       37.119589
# 1      AAL       41.106203
# 2      AAP       33.672927
# 3     AAPL       29.697883
# 4     ABBV       59.048038
# ..     ...             ...
# 498    YUM       38.338165
# 499    ZBH       43.586759
# 500   ZBRA       73.928335
# 501   ZION       68.026810
# 502    ZTS       39.487490
#
# [503 rows x 2 columns]

# %% [markdown]
# # JOIN Ejemplo

# %% [markdown]
# ## Ejemplo long/short vega
#
# Condiciones
#
#
# * Que presenten balances en los proximos 7 dias
# * Que tengan Sigma diaria de las ultimas 40 ruedas menor/mayor a la de las ultimas 120 (mean reversion)
# * Que la volatilidad anualizada HF, PICO en ultimos 15 dias, >+30% / <-30%  al sigma 250 ruedas
# * Que la volatilidad anualizada de las velas de 1min del ultimo dia sea  >+10% / <-10% al sigma 40 ruedas
#
#
# Screener para los tickers que cumplan las condiciones:
#
# * Traer para cada ticker, los 5 contratos de menor/mayor VI
# * Traer para cada ticker, los 5 contratos de mayor vega

# %% [markdown]
# Y si cambio el ejemplo el punto 2-- En vez de buscar un mean reversion buscar una aceleracion 40 vs 120?

# %% [markdown]
# ## Creacion de vistas para parametros de las condiciones

# %%
hoy = datetime.date.today().isoformat()

fecha_limite = datetime.date.today() + datetime.timedelta(days=7)
fecha_limite = fecha_limite.isoformat()

q = f'''CREATE VIEW IF NOT EXISTS bces_7d AS 
        SELECT symbol, EarningsDate FROM sp500_earnings
        WHERE EarningsDate < "{fecha_limite}" AND EarningsDate > "{hoy}"   
    '''

conn.execute(q)

# %%
q = f'''CREATE VIEW IF NOT EXISTS sigmas_diarios AS 
            SELECT symbol, sigma_40, sigma_120, sigma_250
                FROM sp500_daily 
                WHERE Date =
                    (SELECT MAX(Date) FROM sp500_daily)
    '''

conn.execute(q)

# %%
n_dias = 15
q = f'''CREATE VIEW IF NOT EXISTS sigmas_high_freq_{n_dias}d AS 
                    SELECT symbol, round(STDDEV(variacion)*SQRT(250*78),2) AS sigma_hf,
                        MAX(sigma_1d) AS hf_pico_r1d , 
                        MAX(sigma_5d) AS hf_pico_r5d
                    FROM sp500_5m 
                    WHERE Datetime > DATE_SUB(NOW(), INTERVAL {n_dias} day) 
                    GROUP BY symbol'''

conn.execute(q)

# %%
q = '''CREATE VIEW IF NOT EXISTS sigmas_1min AS 
            SELECT symbol, STDDEV(pctChange) * SQRT(390*250) as sigma_intraday 
            FROM  sp500_iex_intraday
            GROUP BY symbol'''

conn.execute(q)

# %% [markdown]
# ## Condiciones

# %%
# %%time
q = '''SELECT * FROM bces_7d AS b
            JOIN sigmas_diarios AS sd
                ON b.symbol = sd.symbol
            JOIN sigmas_high_freq_15d AS shf
                ON sd.symbol = shf.symbol
            JOIN sigmas_1min AS s1m
                ON shf.symbol = s1m.symbol
            
            WHERE sd.sigma_40 < sd.sigma_120
            AND  shf.hf_pico_r1d > sd.sigma_250 * 1.3
            AND s1m.sigma_intraday > sd.sigma_40 * 1.1
    '''

long_vega = pd.read_sql(q, conn)
long_vega
# Out:
# Wall time: 1.4 s
#    symbol EarningsDate symbol  sigma_40  sigma_120  sigma_250 symbol  \
# 0     ABC   2020-11-05    ABC     24.06      26.73      41.55    ABC
# 1     CAH   2020-11-05    CAH     29.45      33.97      44.32    CAH
# 2     DHI   2020-11-10    DHI     40.91      43.80      57.10    DHI
# 3   DISCA   2020-11-05  DISCA     39.56      44.26      49.40  DISCA
# 4      EA   2020-11-05     EA     27.23      27.98      35.22     EA
# 5     FLS   2020-11-05    FLS     41.77      54.26      59.80    FLS
# 6     HFC   2020-11-05    HFC     52.29      60.35      71.29    HFC
# 7     LIN   2020-11-05    LIN     26.26      27.93      38.13    LIN
# 8    MNST   2020-11-05   MNST     25.27      25.45      35.60   MNST
# 9     MYL   2020-11-06    MYL     35.18      38.60      45.03    MYL
# 10   REGN   2020-11-05   REGN     36.97      38.17      42.69   REGN
# 11   TMUS   2020-11-05   TMUS     27.49      27.84      40.57   TMUS
# 12   TTWO   2020-11-05   TTWO     31.64      35.09      40.63   TTWO
# 13    VMC   2020-11-05    VMC     37.23      39.58      52.15    VMC
# 14   XRAY   2020-11-05   XRAY     37.67      40.34      45.11   XRAY
#
#     sigma_hf  hf_pico_r1d  hf_pico_r5d symbol  sigma_intraday
# 0      37.94        54.86       103.30    ABC       41.550608
# 1      39.83        63.77       110.59    CAH       42.691738
# 2      53.23       106.39       143.81    DHI       53.070031
# 3      42.99        65.83       109.49  DISCA       50.772728
# 4      32.90        78.45        94.10     EA       38.611689
# 5      52.60        99.28       135.00    FLS       68.498973
# 6      66.39       101.93       160.97    HFC       73.209484
# 7      31.16        51.56        84.50    LIN       29.202806
# 8      33.69        51.74        88.52   MNST       47.137246
# 9      40.70        61.46       103.09    MYL       48.559479
# 10     37.11        86.86       104.56   REGN       59.117980
# 11     33.32        69.69        86.98   TMUS       42.452951
# 12     33.70        65.61        91.40   TTWO       41.499800
# 13     66.35       177.87       198.35    VMC       89.145250
# 14     57.65       136.10       154.50   XRAY       86.025066

# %%
long_vega_tickers = tuple(long_vega.iloc[:,0])

# %% [markdown]
# ## Screener

# %%
# %%time

screener = {}
for ticker in long_vega_tickers:
    q = f'''SELECT opc.* FROM sp500_opciones opc
                JOIN sigmas_diarios AS sd
                    ON opc.symbol = sd.symbol

                WHERE opc.symbol = "{ticker}"
                    AND opc.ITM = 0
                    AND opc.IV <> 'None'
                
                ORDER BY opc.IV ASC
                LIMIT 5
    '''
    screener[ticker] = pd.read_sql(q, conn)
# Out:
# Wall time: 4.68 s

# %%
screener['ABC']
# Out:
#    index      symbol_opc  Strike  TTM  Type   Bid   Ask  Last      IV  \
# 0    333  ABC_011521C130   130.0   72  CALL  0.25  0.55  0.30  29.232
# 1    361  ABC_021921C140   140.0  107  CALL  0.20  0.45  1.00  29.449
# 2    362  ABC_021921C145   145.0  107  CALL  0.05  0.35  0.76  29.453
# 3    334  ABC_011521C135   135.0   72  CALL  0.10  0.35  0.80  29.459
# 4    360  ABC_021921C135   135.0  107  CALL  0.45  0.70  0.35  29.804
#
#    OpenInt  Theor  delta  gamma   theta   vega    rho  ITM symbol     id
# 0      741    0.4  0.069  0.009  -0.012  0.063  0.014    0    ABC  64234
# 1        5  0.325  0.049  0.006  -0.008  0.058  0.014    0    ABC  64262
# 2       30    0.2  0.032  0.004  -0.005  0.041  0.009    0    ABC  64263
# 3        5  0.225  0.041  0.006  -0.008  0.042  0.008    0    ABC  64235
# 4        3  0.575  0.079  0.008  -0.011  0.085  0.023    0    ABC  64261
